# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
xpoints_l_1 = np.arange(0, 5.5, 0.5)
xpoints_l_2 = np.arange(7.5, 15.5, 0.5)
# xpoints_l = np.array([5, 7.5])
xpoints_l = np.concatenate((xpoints_l_1, [5, 7.5], xpoints_l_2))
# print(xpoints_l)
ypoints_l_1 = np.linspace(6, 6, 11)
ypoints_l_2 = np.linspace(6, 6, 16)
ypoints_l = np.concatenate((ypoints_l_1, [0.5, 0.5], ypoints_l_2))
# print(ypoints_l)
# Out:
# [ 0.   0.5  1.   1.5  2.   2.5  3.   3.5  4.   4.5  5.   5.   7.5  7.5
#   8.   8.5  9.   9.5 10.  10.5 11.  11.5 12.  12.5 13.  13.5 14.  14.5
#  15. ]
# [6.  6.  6.  6.  6.  6.  6.  6.  6.  6.  6.  0.5 0.5 6.  6.  6.  6.  6.
#  6.  6.  6.  6.  6.  6.  6.  6.  6.  6.  6. ]

# %%
xpoints_u = np.arange(0, 15.5, 0.5)
# print(xpoints_u.shape)
# print(xpoints_u.ndim)
print(xpoints_u.size)
ypoints_u = np.linspace(21, 21, xpoints_u.size)
print(ypoints_u.size)
# Out:
# 31
# 31

# %%
xpoints_left = np.array([0, 0])
ypoints_left = np.array([6, 21])

# %%
xpoints_right = np.array([15, 15])
ypoints_right = np.array([6, 21])

# %%
plt.plot(xpoints_l, ypoints_l, 'o:b', ms='4')
plt.plot(xpoints_u, ypoints_u, 'o:b', ms='4')
plt.plot(xpoints_left, ypoints_left, 'o:b', ms='4')
plt.plot(xpoints_right, ypoints_right, 'o:b', ms='4')
plt.xlim([-1, 21])
plt.ylim([-1,22])
yticks_y = np.arange(0, 22, 1)
plt.yticks(yticks_y)
xticks_x = np.arange(0, 21, 1)
plt.xticks(xticks_x)
plt.grid(True)
plt.show()
