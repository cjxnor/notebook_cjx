# %% [markdown]
# # 1.测试画图功能

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
point_x = np.array([1, 2, 3, 4, 5])
point_y = np.array([1, 2, 3, 4, 5])

# %%
plt.plot(point_x, point_y)
plt.grid(True)
plt.show()

# %% [markdown]
# # 2.测试切片

# %%
arr = np.array([[1, 2, 3], [4, 5, 6]])
print(arr)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
arr_2 = arr[-2:, -1:-3:-1]
print(arr_2)
# Out:
# [[3 2]
#  [6 5]]
